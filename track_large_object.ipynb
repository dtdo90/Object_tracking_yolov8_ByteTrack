# %%
import cv2
import torch
import numpy as np

from PIL import Image
from ultralytics import YOLO


# load model
model=YOLO("yolov8s.pt")
print(f"{sum(p.numel() for p in model.parameters())/1e6} million parameters")

# results=model.track("data/box.mov",conf=0.1,show=True)
# Out:
# 11.16656 million parameters

# %% [markdown]
# # Objective
# Assume we want to track **main objects** in a video and draw bounding box in **every single frame**. There are two issues to solve:
#
# 1. Detect the only **large objects** in the video
# 2. If some objects are not detected at a certain frame (for example due to ocllusion), the bounding boxes **will not be drawn** by the usual command model.track

# %% [markdown]
# ### 1. Detect Large Objects
# Idea: Large objects have height (or width) relatively large compared to the image height (or width)

# %%
def detect_large(image_array,ratio=1/5):    
    """
    Detect only large objects, return list [xywh,conf,cls]
    """
    results=[]

    height,width=image_array.shape[:2]

    # prediction with yolo model
    dets=model.predict(image_array,conf=0.1)
    dets=dets[0]            # only 1 input image -> dets = list of length 1
    
    xywhs=dets.boxes.xywh.cpu().numpy()
    confs=dets.boxes.conf.cpu().numpy()
    clss=dets.boxes.cls.cpu().numpy()

    for xywh,conf,cls in zip(xywhs,confs,clss):
        if xywh[2]>width*ratio or xywh[3]*ratio>height*ratio:
            results.append([xywh[0],xywh[1],xywh[2],xywh[3],conf,cls])
    
    return np.asarray(results)

# %% [markdown]
# ## 2. Track with ByteTracker
# We aim to draw bounding boxes in every single frame. In those frames that the model don't detect an object, we use the bounding box of the most recent frame that the object is detected. We need 2 dictionaries:
#
# 1. Dictionary 1: {track_id: bbox}
# 2. Dictionary 2: {track_id: frame_number} with frame_number= most recent frame the track_id was detected

# %%
from argparse import Namespace
from ultralytics.trackers.byte_tracker import BYTETracker

# input to BYTETracker has attributes xywh,conf,cls
class Result:
    def __init__(self,xywh,conf,cls):
        self.xywh=xywh
        self.conf=conf
        self.cls=cls

def inference(video_path):
    cap = cv2.VideoCapture(video_path)
    # video features
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = cap.get(cv2.CAP_PROP_FPS)
    num_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    print(f"Original width : {width} | Original height :{height} | num_frames : {num_frames}")

    # create codec for writing output frame
    out = cv2.VideoWriter(video_path[:-4] + "_tracked.mp4", cv2.VideoWriter_fourcc(*"mp4v"), fps//2, (width, height))
    
    # dictionaries
    history = {}            # dictionary {track_id: bbox}
    frame_history = {}      # dictionary {track_id: frame_number} with frame_number = most recent frame track_id is detected
    buffer = 30             # maximum number of frames to retain information
    
    MIN_BOXES = 2           # minimum number of boxes to draw in every frame 
    last_min_results = None # last result which detects at least 2 boxes

    # activate BYTETracker
    args = Namespace(track_high_thresh=0.5, track_low_thresh=0.1,
                     match_thresh=0.7, new_track_thresh=0.6,
                     track_buffer=buffer, fuse_score=True)
    tracker = BYTETracker(args, frame_rate=fps)

    # loop through frames
    frame_number = 0
    while frame_number < num_frames:
        ret, frame = cap.read()

        if not ret:
            print(f"Failed to read frame {frame_number}. Skipping...")
            frame_number += 1
            continue     

        results = detect_large(frame)
        
        if len(results) < MIN_BOXES:
            results = last_min_results
        else:
            last_min_results = results

        # prepare input for tracker
        xywh = results[:, :4]
        conf = results[:, 4]
        cls = results[:, 5]
        tracker_inputs = Result(xywh, conf, cls)

        # track the frame: tracked_frame=[x1, y1, x2, y2, track_id, score, class, idx]
        tracked_frame = tracker.update(tracker_inputs)
        
        if len(tracked_frame) > 0:
            # extract track results
            track_ids = tracked_frame[:, 4]
            xyxys = tracked_frame[:, :4]
            
            # Update the history with current track_id and bbox
            for track_id, bbox in zip(track_ids, xyxys):
                history[track_id] = bbox
                frame_history[track_id] = frame_number

            # remove track_ids and bboxes that were not seen in the last 30 frames
            for track_id in list(history.keys()):
                if frame_history[track_id] < frame_number - buffer:
                    del history[track_id]
                    del frame_history[track_id]

            for track_id, bbox in history.items():
                cv2.rectangle(frame, (int(bbox[0]), int(bbox[1])), (int(bbox[2]), int(bbox[3])), (0, 255, 0), 2)
                cv2.putText(frame, str(track_id), (int(bbox[0]), int(bbox[1])), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
    
        out.write(frame)
        frame_number += 1

    cap.release()
    out.release()
    cv2.destroyAllWindows()

video_path = "data/box.mov"
inference(video_path)
# Out:
# Original width : 1920 | Original height :1080 | num_frames : 196
#
# 0: 384x640 39 persons, 1 baseball bat, 89.8ms
# Speed: 2.8ms preprocess, 89.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 41 persons, 1 baseball bat, 1 baseball glove, 76.3ms
# Speed: 1.7ms preprocess, 76.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 1 baseball bat, 1 baseball glove, 91.6ms
# Speed: 1.6ms preprocess, 91.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 1 baseball bat, 1 baseball glove, 110.9ms
# Speed: 1.9ms preprocess, 110.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 1 baseball glove, 74.0ms
# Speed: 1.9ms preprocess, 74.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 1 baseball bat, 2 baseball gloves, 88.7ms
# Speed: 1.4ms preprocess, 88.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 1 baseball bat, 2 baseball gloves, 101.1ms
# Speed: 2.1ms preprocess, 101.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 2 baseball bats, 2 baseball gloves, 97.7ms
# Speed: 2.0ms preprocess, 97.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 3 baseball bats, 2 baseball gloves, 75.5ms
# Speed: 2.8ms preprocess, 75.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 3 baseball bats, 2 baseball gloves, 66.8ms
# Speed: 2.0ms preprocess, 66.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 4 baseball bats, 1 baseball glove, 76.2ms
# Speed: 4.2ms preprocess, 76.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 2 baseball bats, 1 baseball glove, 93.0ms
# Speed: 1.8ms preprocess, 93.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 2 sports balls, 1 baseball bat, 1 baseball glove, 71.7ms
# Speed: 1.8ms preprocess, 71.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 2 baseball bats, 1 baseball glove, 92.2ms
# Speed: 2.7ms preprocess, 92.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 2 baseball bats, 1 baseball glove, 83.3ms
# Speed: 1.7ms preprocess, 83.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 2 baseball bats, 1 baseball glove, 79.9ms
# Speed: 1.4ms preprocess, 79.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 2 baseball bats, 1 baseball glove, 90.8ms
# Speed: 1.6ms preprocess, 90.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 2 baseball gloves, 65.8ms
# Speed: 1.5ms preprocess, 65.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 2 baseball gloves, 80.5ms
# Speed: 1.6ms preprocess, 80.5ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 2 baseball gloves, 87.4ms
# Speed: 2.5ms preprocess, 87.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 2 baseball gloves, 100.6ms
# Speed: 1.4ms preprocess, 100.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 1 baseball glove, 83.5ms
# Speed: 2.0ms preprocess, 83.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 1 sports ball, 1 baseball bat, 1 baseball glove, 102.8ms
# Speed: 2.5ms preprocess, 102.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 1 sports ball, 1 baseball glove, 110.1ms
# Speed: 2.1ms preprocess, 110.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 39 persons, 1 baseball bat, 1 baseball glove, 85.0ms
# Speed: 1.5ms preprocess, 85.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 1 sports ball, 1 baseball bat, 87.6ms
# Speed: 3.5ms preprocess, 87.6ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 2 sports balls, 1 baseball bat, 74.7ms
# Speed: 2.7ms preprocess, 74.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 1 sports ball, 84.1ms
# Speed: 2.4ms preprocess, 84.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 113.9ms
# Speed: 3.4ms preprocess, 113.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 95.7ms
# Speed: 1.6ms preprocess, 95.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 75.9ms
# Speed: 1.6ms preprocess, 75.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 kite, 2 baseball bats, 78.5ms
# Speed: 1.8ms preprocess, 78.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 4 sports balls, 1 baseball bat, 98.7ms
# Speed: 1.6ms preprocess, 98.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 sports ball, 1 kite, 2 baseball bats, 91.2ms
# Speed: 2.2ms preprocess, 91.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 sports ball, 1 kite, 1 baseball bat, 81.2ms
# Speed: 4.0ms preprocess, 81.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 kite, 72.2ms
# Speed: 1.6ms preprocess, 72.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 kite, 71.5ms
# Speed: 1.5ms preprocess, 71.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 1 kite, 72.4ms
# Speed: 1.9ms preprocess, 72.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 kite, 71.4ms
# Speed: 1.6ms preprocess, 71.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 kite, 73.8ms
# Speed: 2.0ms preprocess, 73.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 39 persons, 1 kite, 1 baseball bat, 85.0ms
# Speed: 1.7ms preprocess, 85.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 1 kite, 1 baseball bat, 1 bottle, 88.8ms
# Speed: 1.5ms preprocess, 88.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 1 kite, 1 baseball bat, 1 bottle, 86.3ms
# Speed: 2.3ms preprocess, 86.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 1 kite, 1 baseball bat, 87.5ms
# Speed: 1.6ms preprocess, 87.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 sports ball, 2 baseball bats, 1 baseball glove, 78.6ms
# Speed: 1.7ms preprocess, 78.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 sports ball, 1 baseball bat, 76.9ms
# Speed: 1.7ms preprocess, 76.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 1 sports ball, 2 baseball bats, 107.1ms
# Speed: 2.3ms preprocess, 107.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 sports ball, 1 baseball bat, 1 baseball glove, 67.6ms
# Speed: 1.8ms preprocess, 67.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 1 sports ball, 1 kite, 1 baseball bat, 1 baseball glove, 70.9ms
# Speed: 1.8ms preprocess, 70.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 2 sports balls, 1 baseball bat, 1 baseball glove, 65.4ms
# Speed: 2.4ms preprocess, 65.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 sports ball, 1 baseball bat, 1 baseball glove, 82.4ms
# Speed: 1.5ms preprocess, 82.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 2 sports balls, 1 baseball bat, 1 baseball glove, 84.4ms
# Speed: 1.8ms preprocess, 84.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 sports ball, 1 baseball glove, 78.5ms
# Speed: 1.5ms preprocess, 78.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 2 sports balls, 1 baseball glove, 68.9ms
# Speed: 1.7ms preprocess, 68.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 1 baseball bat, 1 baseball glove, 72.6ms
# Speed: 1.7ms preprocess, 72.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 sports ball, 1 baseball bat, 1 baseball glove, 85.2ms
# Speed: 2.2ms preprocess, 85.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 baseball bat, 2 baseball gloves, 91.0ms
# Speed: 1.4ms preprocess, 91.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 1 sports ball, 2 baseball bats, 1 chair, 77.6ms
# Speed: 1.6ms preprocess, 77.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 2 sports balls, 2 baseball bats, 1 chair, 88.0ms
# Speed: 1.7ms preprocess, 88.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 2 sports balls, 1 baseball bat, 2 baseball gloves, 1 chair, 75.5ms
# Speed: 1.9ms preprocess, 75.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 3 sports balls, 1 chair, 81.5ms
# Speed: 1.9ms preprocess, 81.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 2 sports balls, 3 baseball gloves, 85.1ms
# Speed: 1.3ms preprocess, 85.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 2 sports balls, 2 baseball bats, 2 baseball gloves, 82.0ms
# Speed: 1.6ms preprocess, 82.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 2 baseball bats, 3 baseball gloves, 83.6ms
# Speed: 3.8ms preprocess, 83.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 2 baseball bats, 2 baseball gloves, 1 chair, 92.2ms
# Speed: 3.4ms preprocess, 92.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 2 baseball bats, 2 baseball gloves, 94.6ms
# Speed: 3.2ms preprocess, 94.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 2 baseball gloves, 83.6ms
# Speed: 1.6ms preprocess, 83.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 2 baseball bats, 2 baseball gloves, 1 chair, 105.2ms
# Speed: 1.7ms preprocess, 105.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 sports ball, 3 baseball bats, 2 baseball gloves, 92.5ms
# Speed: 1.7ms preprocess, 92.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 2 baseball bats, 2 baseball gloves, 102.2ms
# Speed: 2.1ms preprocess, 102.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 2 baseball bats, 1 baseball glove, 94.5ms
# Speed: 1.7ms preprocess, 94.5ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 1 sports ball, 3 baseball bats, 1 baseball glove, 75.1ms
# Speed: 1.6ms preprocess, 75.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 sports ball, 2 baseball bats, 1 baseball glove, 87.8ms
# Speed: 1.5ms preprocess, 87.8ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 2 baseball bats, 2 baseball gloves, 99.6ms
# Speed: 2.3ms preprocess, 99.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 sports ball, 1 baseball bat, 2 baseball gloves, 100.7ms
# Speed: 2.4ms preprocess, 100.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 sports ball, 2 baseball bats, 3 baseball gloves, 97.8ms
# Speed: 2.9ms preprocess, 97.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 2 baseball bats, 1 baseball glove, 126.1ms
# Speed: 2.5ms preprocess, 126.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 sports ball, 2 baseball bats, 3 baseball gloves, 81.5ms
# Speed: 1.5ms preprocess, 81.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 sports ball, 2 baseball bats, 2 baseball gloves, 93.1ms
# Speed: 2.2ms preprocess, 93.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 2 sports balls, 3 baseball bats, 2 baseball gloves, 87.4ms
# Speed: 1.9ms preprocess, 87.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 2 sports balls, 2 baseball bats, 2 baseball gloves, 84.1ms
# Speed: 2.3ms preprocess, 84.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 3 sports balls, 2 baseball bats, 83.8ms
# Speed: 1.9ms preprocess, 83.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 3 sports balls, 2 baseball bats, 2 baseball gloves, 76.4ms
# Speed: 1.5ms preprocess, 76.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 sports ball, 2 baseball bats, 3 baseball gloves, 91.9ms
# Speed: 1.9ms preprocess, 91.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 sports ball, 2 baseball bats, 2 baseball gloves, 104.4ms
# Speed: 2.9ms preprocess, 104.4ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 1 sports ball, 2 baseball bats, 2 baseball gloves, 98.8ms
# Speed: 2.8ms preprocess, 98.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 sports ball, 2 baseball bats, 3 baseball gloves, 80.5ms
# Speed: 1.7ms preprocess, 80.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 2 baseball bats, 3 baseball gloves, 123.9ms
# Speed: 1.9ms preprocess, 123.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 sports ball, 2 baseball bats, 3 baseball gloves, 73.6ms
# Speed: 2.4ms preprocess, 73.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 sports ball, 2 baseball bats, 3 baseball gloves, 78.6ms
# Speed: 1.5ms preprocess, 78.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 sports ball, 2 baseball bats, 3 baseball gloves, 70.1ms
# Speed: 1.6ms preprocess, 70.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 2 baseball bats, 1 baseball glove, 77.8ms
# Speed: 1.9ms preprocess, 77.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 2 baseball bats, 2 baseball gloves, 90.9ms
# Speed: 1.5ms preprocess, 90.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 2 baseball bats, 1 baseball glove, 126.0ms
# Speed: 2.8ms preprocess, 126.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 2 baseball bats, 2 baseball gloves, 73.7ms
# Speed: 1.7ms preprocess, 73.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 2 baseball bats, 2 baseball gloves, 70.6ms
# Speed: 2.1ms preprocess, 70.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 sports ball, 1 baseball glove, 92.7ms
# Speed: 1.8ms preprocess, 92.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 baseball glove, 84.1ms
# Speed: 1.6ms preprocess, 84.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 sports ball, 1 baseball glove, 85.7ms
# Speed: 1.4ms preprocess, 85.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 2 baseball bats, 1 baseball glove, 86.7ms
# Speed: 3.0ms preprocess, 86.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 sports ball, 2 baseball bats, 1 baseball glove, 77.8ms
# Speed: 2.2ms preprocess, 77.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 sports ball, 2 baseball bats, 1 baseball glove, 81.9ms
# Speed: 1.6ms preprocess, 81.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 2 baseball bats, 1 baseball glove, 82.5ms
# Speed: 1.7ms preprocess, 82.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 1 sports ball, 2 baseball bats, 1 baseball glove, 101.4ms
# Speed: 3.9ms preprocess, 101.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 2 sports balls, 2 baseball bats, 2 baseball gloves, 95.4ms
# Speed: 1.7ms preprocess, 95.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 1 sports ball, 2 baseball bats, 2 baseball gloves, 93.1ms
# Speed: 2.0ms preprocess, 93.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 sports ball, 1 baseball bat, 2 baseball gloves, 84.6ms
# Speed: 1.4ms preprocess, 84.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 3 baseball gloves, 74.5ms
# Speed: 1.4ms preprocess, 74.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 sports ball, 2 baseball gloves, 86.8ms
# Speed: 3.3ms preprocess, 86.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 2 baseball gloves, 88.1ms
# Speed: 1.6ms preprocess, 88.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 baseball glove, 78.4ms
# Speed: 1.6ms preprocess, 78.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 72.2ms
# Speed: 1.4ms preprocess, 72.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 baseball glove, 70.7ms
# Speed: 3.0ms preprocess, 70.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 77.0ms
# Speed: 1.6ms preprocess, 77.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 100.3ms
# Speed: 1.4ms preprocess, 100.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 baseball glove, 109.7ms
# Speed: 1.7ms preprocess, 109.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 baseball bat, 1 baseball glove, 103.1ms
# Speed: 8.4ms preprocess, 103.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 1 baseball glove, 121.8ms
# Speed: 1.8ms preprocess, 121.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 2 baseball gloves, 117.0ms
# Speed: 3.8ms preprocess, 117.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 sports ball, 2 baseball gloves, 74.4ms
# Speed: 1.8ms preprocess, 74.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 3 baseball gloves, 79.2ms
# Speed: 1.7ms preprocess, 79.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 2 baseball gloves, 86.6ms
# Speed: 1.9ms preprocess, 86.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 4 baseball gloves, 111.5ms
# Speed: 8.5ms preprocess, 111.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 sports ball, 3 baseball gloves, 70.8ms
# Speed: 1.9ms preprocess, 70.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 sports ball, 3 baseball gloves, 85.8ms
# Speed: 1.7ms preprocess, 85.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 sports ball, 4 baseball gloves, 78.8ms
# Speed: 1.4ms preprocess, 78.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 3 baseball gloves, 96.5ms
# Speed: 1.3ms preprocess, 96.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 1 sports ball, 3 baseball gloves, 89.9ms
# Speed: 1.9ms preprocess, 89.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 4 baseball gloves, 114.1ms
# Speed: 1.5ms preprocess, 114.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 sports ball, 4 baseball gloves, 78.8ms
# Speed: 2.1ms preprocess, 78.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 2 sports balls, 4 baseball gloves, 79.5ms
# Speed: 2.0ms preprocess, 79.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 3 baseball gloves, 73.8ms
# Speed: 1.8ms preprocess, 73.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 3 baseball gloves, 71.2ms
# Speed: 1.5ms preprocess, 71.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 4 baseball gloves, 68.2ms
# Speed: 1.8ms preprocess, 68.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 sports ball, 1 baseball bat, 3 baseball gloves, 80.9ms
# Speed: 2.5ms preprocess, 80.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 5 baseball gloves, 74.3ms
# Speed: 1.4ms preprocess, 74.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 baseball bat, 3 baseball gloves, 114.3ms
# Speed: 2.2ms preprocess, 114.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 2 baseball bats, 3 baseball gloves, 78.0ms
# Speed: 1.9ms preprocess, 78.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 2 baseball bats, 2 baseball gloves, 79.9ms
# Speed: 1.9ms preprocess, 79.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 baseball bat, 3 baseball gloves, 79.1ms
# Speed: 2.3ms preprocess, 79.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 3 baseball bats, 3 baseball gloves, 64.1ms
# Speed: 1.7ms preprocess, 64.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 2 baseball bats, 1 baseball glove, 65.0ms
# Speed: 6.4ms preprocess, 65.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 2 baseball gloves, 1 cell phone, 87.6ms
# Speed: 3.3ms preprocess, 87.6ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 baseball glove, 1 cell phone, 69.3ms
# Speed: 1.9ms preprocess, 69.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 2 baseball gloves, 1 cell phone, 75.4ms
# Speed: 1.4ms preprocess, 75.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 bench, 1 baseball glove, 64.3ms
# Speed: 2.4ms preprocess, 64.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 baseball glove, 77.0ms
# Speed: 2.3ms preprocess, 77.0ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 sports ball, 1 baseball glove, 114.7ms
# Speed: 5.6ms preprocess, 114.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 sports ball, 2 baseball bats, 2 baseball gloves, 90.3ms
# Speed: 2.5ms preprocess, 90.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 1 sports ball, 3 baseball bats, 75.0ms
# Speed: 1.8ms preprocess, 75.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 1 sports ball, 2 baseball bats, 78.0ms
# Speed: 1.8ms preprocess, 78.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 1 sports ball, 2 baseball bats, 84.3ms
# Speed: 1.6ms preprocess, 84.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 1 sports ball, 2 baseball bats, 1 baseball glove, 77.5ms
# Speed: 1.9ms preprocess, 77.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 1 sports ball, 1 baseball glove, 92.9ms
# Speed: 1.8ms preprocess, 92.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 1 sports ball, 1 baseball bat, 1 baseball glove, 119.0ms
# Speed: 2.5ms preprocess, 119.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 1 sports ball, 85.4ms
# Speed: 2.8ms preprocess, 85.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 40 persons, 1 sports ball, 1 baseball bat, 2 baseball gloves, 91.6ms
# Speed: 1.6ms preprocess, 91.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 1 baseball glove, 78.5ms
# Speed: 2.7ms preprocess, 78.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 1 sports ball, 1 baseball bat, 75.1ms
# Speed: 1.9ms preprocess, 75.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 1 sports ball, 2 baseball gloves, 110.6ms
# Speed: 2.1ms preprocess, 110.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 sports ball, 1 baseball bat, 1 baseball glove, 95.6ms
# Speed: 2.1ms preprocess, 95.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 baseball bat, 3 baseball gloves, 80.3ms
# Speed: 2.0ms preprocess, 80.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 4 baseball gloves, 93.3ms
# Speed: 2.6ms preprocess, 93.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 baseball bat, 2 baseball gloves, 98.4ms
# Speed: 1.8ms preprocess, 98.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 1 sports ball, 2 baseball bats, 2 baseball gloves, 100.1ms
# Speed: 1.9ms preprocess, 100.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 3 baseball bats, 1 baseball glove, 95.5ms
# Speed: 13.4ms preprocess, 95.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 1 sports ball, 3 baseball bats, 1 baseball glove, 82.8ms
# Speed: 1.5ms preprocess, 82.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 sports ball, 1 baseball bat, 88.3ms
# Speed: 1.8ms preprocess, 88.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 1 sports ball, 1 baseball glove, 73.6ms
# Speed: 2.0ms preprocess, 73.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 39 persons, 1 baseball bat, 1 baseball glove, 76.8ms
# Speed: 1.3ms preprocess, 76.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 41 persons, 1 baseball bat, 89.9ms
# Speed: 1.9ms preprocess, 89.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 39 persons, 1 sports ball, 2 baseball gloves, 83.6ms
# Speed: 4.1ms preprocess, 83.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 sports ball, 1 baseball bat, 1 baseball glove, 76.5ms
# Speed: 3.2ms preprocess, 76.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 2 sports balls, 2 baseball bats, 77.6ms
# Speed: 1.7ms preprocess, 77.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 2 sports balls, 1 baseball bat, 93.8ms
# Speed: 3.6ms preprocess, 93.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 3 sports balls, 1 baseball bat, 129.8ms
# Speed: 2.1ms preprocess, 129.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 1 sports ball, 1 baseball bat, 1 tennis racket, 87.3ms
# Speed: 1.8ms preprocess, 87.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 2 sports balls, 1 baseball bat, 1 tennis racket, 88.5ms
# Speed: 1.9ms preprocess, 88.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 5 sports balls, 1 baseball bat, 106.7ms
# Speed: 1.9ms preprocess, 106.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 5 sports balls, 1 baseball bat, 76.7ms
# Speed: 2.0ms preprocess, 76.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 2 sports balls, 77.2ms
# Speed: 1.5ms preprocess, 77.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 1 sports ball, 74.2ms
# Speed: 1.6ms preprocess, 74.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 sports ball, 1 tennis racket, 81.2ms
# Speed: 1.5ms preprocess, 81.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 2 tennis rackets, 110.6ms
# Speed: 1.3ms preprocess, 110.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 1 baseball glove, 1 tennis racket, 70.1ms
# Speed: 1.4ms preprocess, 70.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 1 tennis racket, 73.0ms
# Speed: 1.7ms preprocess, 73.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 1 tennis racket, 83.7ms
# Speed: 1.7ms preprocess, 83.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 1 tennis racket, 84.3ms
# Speed: 1.5ms preprocess, 84.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 baseball bat, 1 tennis racket, 70.6ms
# Speed: 2.0ms preprocess, 70.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 1 tennis racket, 90.4ms
# Speed: 1.8ms preprocess, 90.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Failed to read frame 190. Skipping...
# Failed to read frame 191. Skipping...
# Failed to read frame 192. Skipping...
# Failed to read frame 193. Skipping...
# Failed to read frame 194. Skipping...
# Failed to read frame 195. Skipping...
